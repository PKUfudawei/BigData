# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./breast_cancer.csv')
df.fillna({k: df.mean(skipna=True)[k] for k in df.columns if df[k].isnull().any()}, inplace=True)

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
from sklearn import linear_model
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Out:
# /Users/DaweiFu/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
model = linear_model.LogisticRegression()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
print(accuracy_score(y_true=y_test, y_pred=y_predict))
# Out:
# 0.9824561403508771
# /Users/DaweiFu/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
cm = confusion_matrix(y_true=y_test, y_pred=y_predict)
pd.DataFrame(data={'预测不患癌症': cm[:, 0], '预测患癌症': cm[:, 1]}, index=['实际患癌症', '实际不患癌症'])
# Out:
#         预测不患癌症  预测患癌症
# 实际患癌症       45      0
# 实际不患癌症       2     67

# %%
print('k_0:', model.intercept_)
print('k_1 ~ k_30:', model.coef_)
# Out:
# k_0: [0.21647276]
# k_1 ~ k_30: [[ 1.08593442  0.29773749  0.19279967 -0.01243578 -0.04737156 -0.20032599
#   -0.28848246 -0.12606566 -0.05770798 -0.01090269  0.05240462  0.55950665
#    0.28184453 -0.08787419 -0.00439637 -0.03840022 -0.06108633 -0.01691103
#   -0.01742445 -0.00248244  1.149355   -0.43558281 -0.21776817 -0.01599967
#   -0.08216659 -0.5775676  -0.75738065 -0.23796901 -0.19666855 -0.04783856]]

# %%
model.intercept_ + X_test * model.coef_
# Out:
# array([[15.10463364,  6.41834466, 17.6070034 , ...,  0.17944478,
#          0.15361749,  0.21096654],
#        [13.51916939,  6.89770202, 15.28955132, ...,  0.20139742,
#          0.15550551,  0.21254856],
#        [14.31190152,  5.97769317, 16.51190125, ...,  0.19301377,
#          0.14575075,  0.21208787],
#        ...,
#        [15.65846019,  8.50846183, 18.06008264, ...,  0.19691408,
#          0.1793024 ,  0.21274326],
#        [12.45495366,  4.83140384, 14.36411288, ...,  0.19678796,
#          0.17405135,  0.21148319],
#        [15.7344756 ,  5.22441733, 17.62628337, ...,  0.20854125,
#          0.16813163,  0.21354504]])

# %%
np.shape(X_test), np.shape(model.coef_), np.shape(np.dot(X_test, model.coef_.reshape(-1)))
# Out:
# ((114, 30), (1, 30), (114,))

# %%
y = np.dot(X_test, model.coef_.reshape(-1))

# %%
f_y = 1 / (1 + np.exp(-y))

# %%
df_scatter = pd.DataFrame({'y': y, 'f(y)': f_y, 'label': ['positive' if label==1 else 'negative' for label in y_test]})

# %%
import plotly.express as px
fig = px.scatter(df_scatter, x="y", y="f(y)", color='label', color_discrete_sequence=['blue', 'red'])
fig.update_traces(marker=dict(size=5))
fig.show()
fig.write_image('./scatter.png')
# Out:
# <div>                            <div id="67d3c719-a03a-4083-8c40-9d2ad9620fa8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67d3c719-a03a-4083-8c40-9d2ad9620fa8")) {                    Plotly.newPlot(                        "67d3c719-a03a-4083-8c40-9d2ad9620fa8",                        [{"hovertemplate":"label=negative<br>y=%{x}<br>f(y)=%{y}<extra></extra>","legendgroup":"negative","marker":{"color":"blue","symbol":"circle","size":5},"mode":"markers","name":"negative","orientation":"v","showlegend":true,"x":[-3.0068404366983543,-42.316021480299085,-4.964968161571648,-3.4127776468074322,-0.8532598895115816,-34.329581033141956,-2.6192066904611337,-13.88574711203366,-21.136980755408707,-20.394115419915007,-4.499972830128218,-1.1216454345529376,-23.664118708513676,-11.719459076333095,-14.858681094729043,-0.7277666727113231,-17.04000126437649,-7.0061201021179045,-18.16543489013649,-39.55218287729109,-14.405387193235198,-17.337099065079013,-27.559693102367024,-19.4142089861991,-10.035566037204225,-5.5082143775189705,-0.9773398587285448,-6.383500418229822,-24.980992794548218,-17.020763285153038,-19.256467217001216,-26.896389220114628,-15.160362121988145,-4.444460432145259,-6.230887920838336,-5.511642626309851,-16.386032189308647,-11.669525345603482,-7.885198126668731,-13.43230705808521,-20.5015591893559,-20.05673556133811,-17.366539212329783,-23.56467617446752,-8.614747859720778],"xaxis":"x","y":[0.04711780003198392,4.191653501794466e-19,0.006929815429529522,0.031898509375544136,0.29874946872891056,1.2326857946854434e-15,0.06791249316736543,9.321724154926656e-07,6.611894168591679e-10,1.38978688555263e-09,0.010987237868584123,0.24570619990688333,5.28206602801706e-11,8.1339230542695e-06,3.523356913952967e-07,0.32568500691852714,3.9776032515524536e-08,0.0009054975286979836,1.2907789081291136e-08,6.6482176527578604e-18,5.543953660337028e-07,2.9552452706360886e-08,1.0739334328298584e-12,3.7026798713925576e-09,4.381169137391158e-05,0.00403697542920052,0.2734199325971025,0.0016863511065598866,1.4154439512763673e-11,4.0548650951648884e-08,4.335333831164072e-09,2.0847144591240377e-12,2.605783162951644e-07,0.011607133026453881,0.0019638397002462137,0.004023214954023689,7.64956266437007e-08,8.550387999147156e-06,0.00037613052722128856,1.4669743772244066e-06,1.2482051586022032e-09,1.947468401870323e-09,2.8695106296841373e-08,5.834332413072625e-11,0.00018137764681406166],"yaxis":"y","type":"scatter"},{"hovertemplate":"label=positive<br>y=%{x}<br>f(y)=%{y}<extra></extra>","legendgroup":"positive","marker":{"color":"red","symbol":"circle","size":5},"mode":"markers","name":"positive","orientation":"v","showlegend":true,"x":[0.6345397351946344,3.606205153470044,4.1678811540230525,4.614110272221168,4.452927214151395,5.707275346617436,3.6950991027665716,3.557736932436148,2.2987578934894466,3.896483809898177,5.12558029912007,6.620826145474577,4.652406375677338,5.288058704705421,2.4329315775780174,8.709844715871162,0.6981174223448668,5.192293533626548,3.2217017147365294,8.153087832028534,6.434933549811175,5.794160266809238,3.3902944865915385,-0.8788577750123825,1.8552811506922462,0.2757625490038188,5.560126609815129,4.110404411551787,6.234346080734236,3.1649432016562447,2.168332504507,4.977015645109389,4.185530258518066,6.670608234880431,6.515807021936063,3.9969535687447983,0.9422124277404874,3.0644547020355772,7.206836052571213,2.1751077635076412,6.388795406962534,2.3539195854664263,2.2774599738772343,2.8996302042281537,4.098055606869023,5.237142436352242,2.9126779878159903,1.8256108731189247,2.315917770714047,5.8245821100779365,3.2972897818524007,1.7449390058374965,1.5031996147851163,1.2527294770974817,5.069182996647859,5.720585710446078,6.528048778642512,5.224303035336974,2.4074038550540218,3.956304160070197,3.02 ...
