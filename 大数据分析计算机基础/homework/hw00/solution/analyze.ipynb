# %%
import numpy as np
import pandas as pd

# 显示行列数
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)

# 对齐
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)

# %%
with open('./contestData.txt', mode='r') as f:
    text=f.read().replace(',', ' ').split()
    
text
# Out:
# ['2022004762',
#  '王维(强烈推荐)',
#  '张飞(强烈推荐)',
#  '潘金莲(强烈推荐)',
#  '2022037724',
#  '蒋晶晶(强烈推荐)',
#  '蔡旭(强烈推荐)',
#  '张俐(强烈推荐)',
#  '2022036563',
#  '章习武(强烈推荐)',
#  '柳金梅(强烈推荐)',
#  '陆雅(强烈推荐)',
#  '2022012759',
#  '蒋晶晶(强烈推荐)',
#  '蔡旭(强烈推荐)',
#  '张俐(强烈推荐)',
#  '2022008666',
#  '郑永健(强烈推荐)',
#  '张岸(强烈推荐)',
#  '熊莹莹(强烈推荐)',
#  '2022023839',
#  '王维(强烈推荐)',
#  '张飞(推荐)',
#  '潘金莲(强烈推荐)',
#  '2022032429',
#  '郑永健(推荐)',
#  '张岸(强烈推荐)',
#  '熊莹莹(强烈推荐)',
#  '2022044502',
#  '蒋晶晶(推荐)',
#  '蔡旭(强烈推荐)',
#  '张俐(强烈推荐)',
#  '2022040832',
#  '郑永健(推荐)',
#  '张岸(强烈推荐)',
#  '熊莹莹(强烈推荐)',
#  '2022009627',
#  '姚娜(推荐)',
#  '高铁塔(强烈推荐)',
#  '王文文(强烈推荐)',
#  '2022008646',
#  '姚娜(强烈推荐)',
#  '高铁塔(强烈推荐)',
#  '王文文(推荐)',
#  '2022038734',
#  '王晓黎(推荐)',
#  '程明远(强烈推荐)',
#  '黄新智(强烈推荐)',
#  '2022038733',
#  '王晓黎(推荐)',
#  '程明远(强烈推荐)',
#  '黄新智(强烈推荐)',
#  '2022032396',
#  '姚娜(强烈推荐)',
#  '高铁塔(推荐)',
#  '王文文(强烈推荐)',
#  '2022033535',
#  '魏巍(推荐)',
#  '刘菊红(强烈推荐)',
#  '韩华静(强烈推荐)',
#  '2022010256',
#  '王维(强烈推荐)',
#  '张飞(推荐)',
#  '潘金莲(推荐)',
#  '2022043803',
#  '姚娜(推荐)',
#  '高铁塔(强烈推荐)',
#  '王文文(推荐)',
#  '2022043818',
#  '夏鸿声(强烈推荐)',
#  '许娟娟(不推荐)',
#  '唐仁轨(强烈推荐)',
#  '2022009807',
#  '曹超(推荐)',
#  '鲁智仁(推荐)',
#  '魏青云(强烈推荐)',
#  '2022042895',
#  '程红世(强烈推荐)',
#  '牛紫气(推荐)',
#  '王大伟(推荐)',
#  '2022022206',
#  '刘晓东(推荐)',
#  '李美吉(强烈推荐)',
#  '张鸣(推荐)',
#  '2022021374',
#  '魏巍(推荐)',
#  '刘菊红(推荐)',
#  '韩华静(强烈推荐)',
#  '2022013148',
#  '刘晓东(推荐)',
#  '李美吉(推荐)',
#  '张鸣(强烈推荐)',
#  '2022002221',
#  '章力(强烈推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022004205',
#  '王维(推荐)',
#  '张飞(强烈推荐)',
#  '潘金莲(推荐)',
#  '2022002450',
#  '曹超(推荐)',
#  '鲁智仁(推荐)',
#  '魏青云(强烈推荐)',
#  '2022043837',
#  '蒋晶晶(推荐)',
#  '蔡旭(推荐)',
#  '张俐(强烈推荐)',
#  '2022044685',
#  '章力(强烈推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022033171',
#  '章力(强烈推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022042859',
#  '程红世(推荐)',
#  '牛紫气(推荐)',
#  '王大伟(强烈推荐)',
#  '2022007435',
#  '姚娜(强烈推荐)',
#  '高铁塔(推荐)',
#  '王文文(推荐)',
#  '2022039962',
#  '章力(强烈推荐)',
#  '刘明智(不推荐)',
#  '陈莞尔(强烈推荐)',
#  '2022011337',
#  '夏鸿声(强烈推荐)',
#  '许娟娟(推荐)',
#  '唐仁轨(推荐)',
#  '2022033892',
#  '章力(强烈推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022026446',
#  '章力(强烈推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022024836',
#  '魏巍(强烈推荐)',
#  '刘菊红(推荐)',
#  '韩华静(推荐)',
#  '2022007669',
#  '夏鸿声(强烈推荐)',
#  '许娟娟(不推荐)',
#  '唐仁轨(强烈推荐)',
#  '2022036545',
#  '章力(强烈推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022004833',
#  '王维(强烈推荐)',
#  '张飞(推荐)',
#  '潘金莲(推荐)',
#  '2022035468',
#  '姚娜(推荐)',
#  '高铁塔(推荐)',
#  '王文文(强烈推荐)',
#  '2022008933',
#  '王晓黎(不推荐)',
#  '程明远(强烈推荐)',
#  '黄新智(强烈推荐)',
#  '2022006784',
#  '王维(强烈推荐)',
#  '张飞(推荐)',
#  '潘金莲(推荐)',
#  '2022004742',
#  '蒋晶晶(强烈推荐)',
#  '蔡旭(推荐)',
#  '张俐(推荐)',
#  '2022005182',
#  '程红世(推荐)',
#  '牛紫气(推荐)',
#  '王大伟(强烈推荐)',
#  '2022035133',
#  '魏巍(强烈推荐)',
#  '刘菊红(不推荐)',
#  '韩华静(强烈推荐)',
#  '2022037540',
#  '王晓黎(推荐)',
#  '程明远(推荐)',
#  '黄新智(强烈推荐)',
#  '2022034793',
#  '章习武(强烈推荐)',
#  '柳金梅(推荐)',
#  '陆雅(推荐)',
#  '2022041885',
#  '吴和伟(强烈推荐)',
#  '李八通(不推荐)',
#  '陈洁虹(强烈推荐)',
#  '2022038331',
#  '魏巍(强烈推荐)',
#  '刘菊红(推荐)',
#  '韩华静(推荐)',
#  '2022038044',
#  '蒋晶晶(强烈推荐)',
#  '蔡旭(推荐)',
#  '张俐(推荐)',
#  '2022038982',
#  '程红世(强烈推荐)',
#  '牛紫气(推荐)',
#  '王大伟(推荐)',
#  '2022005391',
#  '王维(推荐)',
#  '张飞(强烈推荐)',
#  '潘金莲(推荐)',
#  '2022033971',
#  '蒋晶晶(强烈推荐)',
#  '蔡旭(强烈推荐)',
#  '张俐(不推荐)',
#  '2022041206',
#  '魏巍(推荐)',
#  '刘菊红(推荐)',
#  '韩华静(强烈推荐)',
#  '2022039883',
#  '章习武(强烈推荐)',
#  '柳金梅(不推荐)',
#  '陆雅(推荐)',
#  '2022005829',
#  '刘晓东(推荐)',
#  '李美吉(推荐)',
#  '张鸣(推荐)',
#  '2022043739',
#  '蒋晶晶(推荐)',
#  '蔡旭(推荐)',
#  '张俐(推荐)',
#  '2022002460',
#  '吴和伟(推荐)',
#  '李八通(不推荐)',
#  '陈洁虹(强烈推荐)',
#  '2022006231',
#  '刘晓东(推荐)',
#  '李美吉(强烈推荐)',
#  '张鸣(不推荐)',
#  '2022043983',
#  '魏巍(不推荐)',
#  '刘菊红(强烈推荐)',
#  '韩华静(推荐)',
#  '2022043930',
#  '程红世(推荐)',
#  '牛紫气(推荐)',
#  '王大伟(推荐)',
#  '2022041253',
#  '蒋晶晶(推荐)',
#  '蔡旭(推荐)',
#  '张俐(推荐)',
#  '2022041494',
#  '曹超(推荐)',
#  '鲁智仁(不推荐)',
#  '魏青云(强烈推荐)',
#  '2022005377',
#  '夏鸿声(强烈推荐)',
#  '许娟娟(推荐)',
#  '唐仁轨(不推荐)',
#  '2022044137',
#  '夏鸿声(不推荐)',
#  '许娟娟(强烈推荐)',
#  '唐仁轨(推荐)',
#  '2022038271',
#  '蒋晶晶(推荐)',
#  '蔡旭(推荐)',
#  '张俐(推荐)',
#  '2022044212',
#  '程红世(推荐)',
#  '牛紫气(推荐)',
#  '王大伟(推荐)',
#  '2022005295',
#  '章力(推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022006385',
#  '章力(推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022005317',
#  '吴和伟(不推荐)',
#  '李八通(推荐)',
#  '陈洁虹(强烈推荐)',
#  '2022045875',
#  '蒋晶晶(不推荐)',
#  '蔡旭(强烈推荐)',
#  '张俐(推荐)',
#  '2022005264',
#  '姚娜(推荐)',
#  '高铁塔(推荐)',
#  '王文文(推荐)',
#  '2022038060',
#  '蒋晶晶(强烈推荐)',
#  '蔡旭(不推荐)',
#  '张俐(推荐)',
#  '2022043693',
#  '程红世(推荐)',
#  '牛紫气(推荐)',
#  '王大伟(推荐)',
#  '2022037936',
#  '魏巍(推荐)',
#  '刘菊红(推荐)',
#  '韩华静(推荐)',
#  '2022037057',
#  '夏鸿声(推荐)',
#  '许娟娟(强烈推荐)',
#  '唐仁轨(不推荐)',
#  '2022037451',
#  '蒋晶晶(不推荐)',
#  '蔡旭(推荐)',
#  '张俐(强烈推荐)',
#  '2022043596',
#  '夏鸿声(不推荐)',
#  '唐仁轨(推荐)',
#  '许娟娟(强烈推荐)',
#  '2022037563',
#  '郑永健(推荐)',
#  '张岸(推荐)',
#  '熊莹莹(推荐)',
#  '2022037493',
#  '魏巍(推荐)',
#  '刘菊红(推荐)',
#  '韩华静(推荐)',
#  '2022042735',
#  '章习武(推荐)',
#  '柳金梅(强烈推荐)',
#  '陆雅(不推荐)',
#  '2022004994',
#  '章力(推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022007333',
#  '吴和伟(推荐)',
#  '李八通(不推荐)',
#  '陈洁虹(强烈推荐)',
#  '2022042759',
#  '章习武(强烈推荐)',
#  '柳金梅(不推荐)',
#  '陆雅(推荐)',
#  '2022037427',
#  '魏巍(推荐)',
#  '刘菊红(不推荐)',
#  '韩华静(强烈推荐)',
#  '2022043595',
#  '夏鸿声(推荐)',
#  '唐仁轨(推荐)',
#  '许娟娟(推荐)',
#  '2022037379',
#  '蒋晶晶(推荐)',
#  '蔡旭(强烈推荐)',
#  '张俐(不推荐)',
#  '2022042875',
#  '郑永健(不推荐)',
#  '张岸(推荐)',
#  '熊莹莹(强烈推荐)',
#  '2022040442',
#  '魏巍(推荐)',
#  '刘菊红(强烈推荐)',
#  '韩华静(不推荐)',
#  '2022042810',
#  '姚娜(推荐)',
#  '高铁塔(强烈推荐)',
#  '王文文(不推荐)',
#  '2022010865',
#  '章习武(推荐)',
#  '柳金梅(强烈推荐)',
#  '陆雅(不推荐)',
#  '2022043462',
#  '夏鸿声(推荐)',
#  '许娟娟(强烈推荐)',
#  '唐仁轨(不推荐)',
#  '2022036797',
#  '章习武(推荐)',
#  '柳金梅(强烈推荐)',
#  '陆雅(不推荐)',
#  '2022010712',
#  '曹超(推荐)',
#  '鲁智仁(推荐)',
#  '魏青云(推荐)',
#  '2022007482',
#  '郑永健(推荐)',
#  '张岸(推荐)',
#  '熊莹莹(推荐)',
#  '2022036379',
#  '刘晓东(推荐)',
#  '李美吉(推荐)',
#  '张鸣(推荐)',
#  '2022027325',
#  '吴和伟(不推荐)',
#  '李八通(强烈推荐)',
#  '陈洁虹(推荐)',
#  '2022012508',
#  '曹超(推荐)',
#  '鲁智仁(推荐)',
#  '魏青云(推荐)',
#  '2022035745',
#  '章力(推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022035596',
#  '刘晓东(推荐)',
#  '李美吉(推荐)',
#  '张鸣(推荐)',
#  '2022007673',
#  '曹超(推荐)',
#  '鲁智仁(不推荐)',
#  '魏青云(强烈推荐)',
#  '2022011629',
#  '郑永健(推荐)',
#  '张岸(推荐)',
#  '熊莹莹(推荐)',
#  '2022011541',
#  '章习武(强烈推荐)',
#  '柳金梅(推荐)',
#  '陆雅(不推荐)',
#  '2022034999',
#  '吴和伟(推荐)',
#  '李八通(不推荐)',
#  '陈洁虹(强烈推荐)',
#  '2022013031',
#  '程红世(强烈推荐)',
#  '牛紫气(不推荐)',
#  '王大伟(推荐)',
#  '2022015610',
#  '王晓黎(推荐)',
#  '程明远(推荐)',
#  '黄新智(推荐)',
#  '2022013248',
#  '魏巍(不推荐)',
#  '刘菊红(推荐)',
#  '韩华静(强烈推荐)',
#  '2022016265',
#  '章习武(推荐)',
#  '柳金梅(推荐)',
#  '陆雅(推荐)',
#  '2022019934',
#  '刘晓东(推荐)',
#  '李美吉(不推荐)',
#  '张鸣(强烈推荐)',
#  '2022014534',
#  '蒋晶晶(推荐)',
#  '蔡旭(推荐)',
#  '张俐(推荐)',
#  '2022010097',
#  '吴和伟(推荐)',
#  '李八通(强烈推荐)',
#  '陈洁虹(不推荐)',
#  '2022020668',
#  '魏巍(强烈推荐)',
#  '刘菊红(推荐)',
#  '韩华静(不推荐)',
#  '2022020468',
#  '魏巍(推荐)',
#  '刘菊红(推荐)',
#  '韩华静(推荐)',
#  '2022009981',
#  '郑永健(推荐)',
#  '张岸(推荐)',
#  '熊莹莹(推荐)',
#  '2022021822',
#  '吴和伟(推荐)',
#  '李八通(强烈推荐)',
#  '陈洁虹(不推荐)',
#  '2022009928',
#  '吴和伟(不推荐)',
#  '李八通(强烈推荐)',
#  '陈洁虹(推荐)',
#  '2022021682',
#  '曹超(推荐)',
#  '鲁智仁(推荐)',
#  '魏青云(推荐)',
#  '2022023017',
#  '王维(强烈推荐)',
#  '张飞(推荐)',
#  '潘金莲(不推荐)',
#  '2022027458',
#  '夏鸿声(推荐)',
#  '许娟娟(不推荐)',
#  '唐仁轨(强烈推荐)',
#  '2022023915',
#  '刘晓东(不推荐)',
#  '李美吉(强烈推荐)',
#  '张鸣(推荐)',
#  '2022023637',
#  '曹超(推荐)',
#  '鲁智仁(不推荐)',
#  '魏青云(强烈推荐)',
#  '2022032470',
#  '王晓黎(推荐)',
#  '程明远(推荐)',
#  '黄新智(推荐)',
#  '2022030692',
#  '王晓黎(推荐)',
#  '程明远(强烈推荐)',
#  '黄新智(不推荐)',
#  '2022009413',
#  '吴和伟(不推荐)',
#  '李八通(强烈推荐)',
#  '陈洁虹(推荐)',
#  '2022023021',
#  '姚娜(推荐)',
#  '高铁塔(不推荐)',
#  '王文文(强烈推荐)',
#  '2022000207',
#  '章习武(推荐)',
#  '柳金梅(推荐)',
#  '陆雅(推荐)',
#  '2022024141',
#  '刘晓东(推荐)',
#  '李美吉(推荐)',
#  '张鸣(推荐)',
#  '2022031019',
#  '程红世(推荐)',
#  '牛紫气(推荐)',
#  '王大伟(推荐)',
#  '2022026457',
#  '蒋晶晶(推荐)',
#  '蔡旭(推荐)',
#  '张俐(推荐)',
#  '2022030163',
#  '程红世(推荐)',
#  '牛紫气(推荐)',
#  '王大伟(推荐)',
#  '2022026898',
#  '郑永健(推荐)',
#  '张岸(强烈推荐)',
#  '熊莹莹(不推荐)',
#  '2022028866',
#  '姚娜(推荐)',
#  '高铁塔(推荐)',
#  '王文文(推荐)',
#  '2022024705',
#  '王晓黎(推荐)',
#  '程明远(推荐)',
#  '黄新智(推荐)',
#  '2022029529',
#  '蒋晶晶(推荐)',
#  '蔡旭(强烈推荐)',
#  '张俐(不推荐)',
#  '2022029550',
#  '刘晓东(不推荐)',
#  '李美吉(推荐)',
#  '张鸣(强烈推荐)',
#  '2022009405',
#  '姚娜(推荐)',
#  '高铁塔(不推荐)',
#  '王文文(推荐)',
#  '2022009371',
#  '章力(推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(不推荐)',
#  '2022004897',
#  '刘晓东(不推荐)',
#  '李美吉(不推荐)',
#  '张鸣(强烈推荐)',
#  '2022004917',
#  '曹超(不推荐)',
#  '鲁智仁(强烈推荐)',
#  '魏青云(不推荐)',
#  '2022005262',
#  '章习武(推荐)',
#  '柳金梅(不推荐)',
#  '陆雅(推荐)',
#  '2022005140',
#  '刘晓东(不推荐)',
#  '李美吉(推荐)',
#  '张鸣(推荐)',
#  '2022004309',
#  '王维(推荐)',
#  '张飞(不推荐)',
#  '潘金莲(推荐)',
#  '2022009059',
#  '程红世(推荐)',
#  '牛紫气(不推荐)',
#  '王大伟(推荐)',
#  '2022009020',
#  '章习武(推荐)',
#  '柳金梅(不推荐)',
#  '陆雅(推荐)',
#  '2022005136',
#  '章力(不推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022005114',
#  '刘晓东(推荐)',
#  '李美吉(不推荐)',
#  '张鸣(推荐)',
#  '2022008789',
#  '王晓黎(推荐)',
#  '程明远(推荐)',
#  '黄新智(不推荐)',
#  '2022008847',
#  '章习武(不推荐)',
#  '柳金梅(推荐)',
#  '陆雅(推荐)',
#  '2022004215',
#  '程红世(推荐)',
#  '牛紫气(不推荐)',
#  '王大伟(推荐)',
#  '2022000319',
#  '曹超(推荐)',
#  '鲁智仁(推荐)',
#  '魏青云(不推荐)',
#  '2022004187',
#  '郑永健(推荐)',
#  '张岸(推荐)',
#  '熊莹莹(不推荐)',
#  '2022001997',
#  '曹超(不推荐)',
#  '鲁智仁(推荐)',
#  '魏青云(推荐)',
#  '2022009949',
#  '刘晓东(推荐)',
#  '李美吉(不推荐)',
#  '张鸣(推荐)',
#  '2022008744',
#  '章力(推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(不推荐)',
#  '2022000451',
#  '章力(不推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022005214',
#  '曹超(不推荐)',
#  '鲁智仁(推荐)',
#  '魏青云(推荐)',
#  '2022001183',
#  '曹超(不推荐)',
#  '鲁智仁(推荐)',
#  '魏青云(推荐)',
#  '2022005409',
#  '刘晓东(不推荐)',
#  '李美吉(不推荐)',
#  '张鸣(强烈推荐)',
#  '2022008446',
#  '曹超(推荐)',
#  '鲁智仁(不推荐)',
#  '魏青云(推荐)',
#  '2022005359',
#  '王晓黎(不推荐)',
#  '程明远(推荐)',
#  '黄新智(推荐)',
#  '2022008230',
#  '刘晓东(不推荐)',
#  '李美吉(强烈推荐)',
#  '张鸣(不推荐)',
#  '2022005651',
#  '刘晓东(不推荐)',
#  '李美吉(强烈推荐)',
#  '张鸣(不推荐)',
#  '2022010215',
#  '章习武(推荐)',
#  '柳金梅(不推荐)',
#  '陆雅(推荐)',
#  '2022008418',
#  '程红世(推荐)',
#  '牛紫气(不推荐)',
#  '王大伟(推荐)',
#  '2022007958',
#  '章力(不推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022005797',
#  '章力(不推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022007113',
#  '曹超(不推荐)',
#  '鲁智仁(不推荐)',
#  '魏青云(强烈推荐)',
#  '2022006329',
#  '姚娜(推荐)',
#  '高铁塔(不推荐)',
#  '王文文(推荐)',
#  '2022007295',
#  '章习武(不推荐)',
#  '柳金梅(不推荐)',
#  '陆雅(强烈推荐)',
#  '2022007383',
#  '章力(推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(不推荐)',
#  '2022000450',
#  '吴和伟(不推荐)',
#  '李八通(推荐)',
#  '陈洁虹(推荐)',
#  '2022007287',
#  '刘晓东(不推荐)',
#  '李美吉(推荐)',
#  '张鸣(推荐)',
#  '2022010358',
#  '刘晓东(推荐)',
#  '李美吉(推荐)',
#  '张鸣(不推荐)',
#  '2022007642',
#  '王维(推荐)',
#  '张飞(推荐)',
#  '潘金莲(不推荐)',
#  '2022009180',
#  '程红世(推荐)',
#  '牛紫气(推荐)',
#  '王大伟(不推荐)',
#  '2022009224',
#  '吴和伟(推荐)',
#  '李八通(不推荐)',
#  '陈洁虹(推荐)',
#  '2022010595',
#  '吴和伟(推荐)',
#  '李八通(不推荐)',
#  '陈洁虹(推荐)',
#  '2022009266',
#  '王维(不推荐)',
#  '张飞(强烈推荐)',
#  '潘金莲(不推荐)',
#  '2022007442',
#  '刘晓东(推荐)',
#  '李美吉(不推荐)',
#  '张鸣(推荐)',
#  '2022007620',
#  '王维(不推荐)',
#  '张飞(推荐)',
#  '潘金莲(推荐)',
#  '2022010737',
#  '吴和伟(推荐)',
#  '李八通(不推荐)',
#  '陈洁虹(推荐)',
#  '2022047827',
#  '曹超(推荐)',
#  '鲁智仁(不推荐)',
#  '魏青云(推荐)',
#  '2022000131',
#  '王晓黎(推荐)',
#  '程明远(推荐)',
#  '黄新智(不推荐)',
#  '2022025132',
#  '郑永健(推荐)',
#  '张岸(不推荐)',
#  '熊莹莹(推荐)',
#  '2022044402',
#  '姚娜(不推荐)',
#  '高铁塔(推荐)',
#  '王文文(推荐)',
#  '2022011260',
#  '郑永健(不推荐)',
#  '张岸(推荐)',
#  '熊莹莹(推荐)',
#  '2022044107',
#  '刘晓东(不推荐)',
#  '李美吉(推荐)',
#  '张鸣(推荐)',
#  '2022024789',
#  '章力(推荐)',
#  '刘明智(不推荐)',
#  '陈莞尔(推荐)',
#  '2022024270',
#  '夏鸿声(推荐)',
#  '许娟娟(推荐)',
#  '唐仁轨(不推荐)',
#  '2022011354',
#  '蒋晶晶(推荐)',
#  '蔡旭(推荐)',
#  '张俐(不推荐)',
#  '2022037399',
#  '章力(推荐)',
#  '刘明智(不推荐)',
#  '陈莞尔(推荐)',
#  '2022037503',
#  '郑永健(强烈推荐)',
#  '张岸(不推荐)',
#  '熊莹莹(不推荐)',
#  '2022043980',
#  '吴和伟(不推荐)',
#  '李八通(强烈推荐)',
#  '陈洁虹(不推荐)',
#  '2022026547',
#  '蒋晶晶(不推荐)',
#  '蔡旭(推荐)',
#  '张俐(推荐)',
#  '2022043836',
#  '牛紫气(推荐)',
#  '王大伟(不推荐)',
#  '程红世(推荐)',
#  '2022043882',
#  '吴和伟(推荐)',
#  '李八通(不推荐)',
#  '陈洁虹(推荐)',
#  '2022043775',
#  '刘晓东(不推荐)',
#  '李美吉(强烈推荐)',
#  '张鸣(不推荐)',
#  '2022043956',
#  '夏鸿声(推荐)',
#  '许娟娟(推荐)',
#  '唐仁轨(不推荐)',
#  '2022024214',
#  '王晓黎(不推荐)',
#  '程明远(不推荐)',
#  '黄新智(强烈推荐)',
#  '2022016118',
#  '王晓黎(推荐)',
#  '程明远(不推荐)',
#  '黄新智(推荐)',
#  '2022012262',
#  '郑永健(不推荐)',
#  '张岸(推荐)',
#  '熊莹莹(推荐)',
#  '2022043967',
#  '魏巍(推荐)',
#  '刘菊红(不推荐)',
#  '韩华静(推荐)',
#  '2022027308',
#  '刘晓东(推荐)',
#  '李美吉(推荐)',
#  '张鸣(不推荐)',
#  '2022027922',
#  '刘晓东(推荐)',
#  '李美吉(推荐)',
#  '张鸣(不推荐)',
#  '2022028950',
#  '蒋晶晶(推荐)',
#  '蔡旭(推荐)',
#  '张俐(不推荐)',
#  '2022043233',
#  '姚娜(推荐)',
#  '高铁塔(不推荐)',
#  '王文文(推荐)',
#  '2022043293',
#  '程红世(推荐)',
#  '牛紫气(推荐)',
#  '王大伟(不推荐)',
#  '2022043170',
#  '魏巍(不推荐)',
#  '刘菊红(推荐)',
#  '韩华静(推荐)',
#  '2022045268',
#  '夏鸿声(强烈推荐)',
#  '许娟娟(不推荐)',
#  '唐仁轨(不推荐)',
#  '2022029720',
#  '章力(不推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022044842',
#  '魏巍(推荐)',
#  '刘菊红(推荐)',
#  '韩华静(不推荐)',
#  '2022043116',
#  '夏鸿声(推荐)',
#  '许娟娟(推荐)',
#  '唐仁轨(不推荐)',
#  '2022012843',
#  '章习武(不推荐)',
#  '柳金梅(推荐)',
#  '陆雅(推荐)',
#  '2022012780',
#  '章力(不推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022043119',
#  '魏巍(不推荐)',
#  '刘菊红(推荐)',
#  '韩华静(推荐)',
#  '2022045452',
#  '吴和伟(不推荐)',
#  '李八通(强烈推荐)',
#  '陈洁虹(不推荐)',
#  '2022043102',
#  '曹超(推荐)',
#  '鲁智仁(推荐)',
#  '魏青云(不推荐)',
#  '2022043547',
#  '章习武(不推荐)',
#  '柳金梅(推荐)',
#  '陆雅(推荐)',
#  '2022023056',
#  '刘晓东(不推荐)',
#  '李美吉(推荐)',
#  '张鸣(推荐)',
#  '2022043036',
#  '夏鸿声(不推荐)',
#  '许娟娟(强烈推荐)',
#  '唐仁轨(不推荐)',
#  '2022037370',
#  '蒋晶晶(不推荐)',
#  '蔡旭(推荐)',
#  '张俐(推荐)',
#  '2022037376',
#  '蒋晶晶(不推荐)',
#  '蔡旭(不推荐)',
#  '张俐(强烈推荐)',
#  '2022013313',
#  '夏鸿声(不推荐)',
#  '许娟娟(推荐)',
#  '唐仁轨(推荐)',
#  '2022042989',
#  '程红世(推荐)',
#  '牛紫气(推荐)',
#  '王大伟(不推荐)',
#  '2022043030',
#  '姚娜(不推荐)',
#  '高铁塔(推荐)',
#  '王文文(推荐)',
#  '2022037137',
#  '曹超(推荐)',
#  '鲁智仁(不推荐)',
#  '魏青云(推荐)',
#  '2022016763',
#  '王维(不推荐)',
#  '张飞(推荐)',
#  '潘金莲(推荐)',
#  '2022042774',
#  '魏巍(推荐)',
#  '刘菊红(推荐)',
#  '韩华静(不推荐)',
#  '2022042765',
#  '吴和伟(不推荐)',
#  '李八通(强烈推荐)',
#  '陈洁虹(不推荐)',
#  '2022013586',
#  '蒋晶晶(不推荐)',
#  '蔡旭(推荐)',
#  '张俐(推荐)',
#  '2022042874',
#  '姚娜(推荐)',
#  '高铁塔(不推荐)',
#  '王文文(推荐)',
#  '2022013457',
#  '程红世(不推荐)',
#  '牛紫气(推荐)',
#  '王大伟(推荐)',
#  '2022042752',
#  '吴和伟(推荐)',
#  '李八通(推荐)',
#  '陈洁虹(不推荐)',
#  '2022030277',
#  '姚娜(推荐)',
#  '高铁塔(不推荐)',
#  '王文文(推荐)',
#  '2022037096',
#  '王晓黎(推荐)',
#  '程明远(推荐)',
#  '黄新智(不推荐)',
#  '2022036896',
#  '吴和伟(推荐)',
#  '李八通(推荐)',
#  '陈洁虹(不推荐)',
#  '2022022549',
#  '章力(不推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  '2022042499',
#  '郑永健(推荐)',
#  '张岸(推荐)',
#  '熊莹莹(不推荐)',
#  '2022032183',
#  '蒋晶晶(推荐)',
#  '蔡旭(推荐)',
#  '张俐(不推荐)',
#  '2022030487',
#  '蒋晶晶(推荐)',
#  '蔡旭(推荐)',
#  '张俐(不推荐)',
#  '2022040869',
#  '王晓黎(推荐)',
#  '程明远(推荐)',
#  '黄新智(不推荐)',
#  '2022014046',
#  '章习武(不推荐)',
#  '柳金梅(不推荐)',
#  '陆雅(强烈推荐)',
#  '2022042621',
#  '魏巍(推荐)',
#  '刘菊红(不推荐)',
#  '韩华静(推荐)',
#  '2022022176',
#  '魏巍(不推荐)',
#  '刘菊红(强烈推荐)',
#  '韩华静(不推荐)',
#  '2022022036',
#  '郑永健(推荐)',
#  '张岸(推荐)',
#  '熊莹莹(不推荐)',
#  '2022041890',
#  '曹超(不推荐)',
#  '鲁智仁(推荐)',
#  '魏青云(推荐)',
#  '2022046596',
#  '魏巍(强烈推荐)',
#  '刘菊红(不推荐)',
#  '韩华静(不推荐)',
#  '2022032781',
#  '程红世(不推荐)',
#  '牛紫气(推荐)',
#  '王大伟(推荐)',
#  '2022040517',
#  '吴和伟(强烈推荐)',
#  '李八通(不推荐)',
#  '陈洁虹(不推荐)',
#  '2022040619',
#  '章力(不推荐)',
#  '刘明智(推荐)',
#  '陈莞尔(推荐)',
#  ...]

# %%
work_category = pd.read_csv('./work_cat.csv')
work_category[0:5]
# Out:
#      作品编号        类别
# 0  2022041494  大数据应用
# 1  2022004917  大数据应用
# 2  2022047827  大数据应用
# 3  2022001997  大数据应用
# 4  2022001183  大数据应用

# %%
work_category[work_category['作品编号']==2022043345]['类别'].to_list()
# Out:
# ['信息可视化设计']

# %%
work_category.query('作品编号==2022043345', inplace=False)
# Out:
#        作品编号            类别
# 795  2022043345  信息可视化设计

# %%
def encode1(lst: list, sort: bool=True):
    out = []
    for s in lst:
        if '强烈推荐' in s:
            out.append('2')
        elif '不推荐' in s:
            out.append('0')
        else:
            out.append('1')
    if sort:
        out.sort(reverse=True) ## from max to min
    return ''.join(out)

data1 = {
    '作品编号': np.array([int(text[i]) for i in range(0, len(text), 4)]),
    '得分构型': np.array([encode1(text[i+1:i+4]) for i in range(0, len(text), 4)])
}
data1['作品类别'] = np.array([
    work_category[work_category['作品编号']==i]['类别'].to_list()[0] for i in data1['作品编号']
])

df1 = pd.DataFrame(data=data1)
df1
# Out:
#        作品编号 得分构型            作品类别
# 0    2022004762      222        人工智能应用
# 1    2022037724      222      数媒动漫与短片
# 2    2022036563      222      信息可视化设计
# 3    2022012759      222      数媒动漫与短片
# 4    2022008666      222        数媒静态设计
# ..          ...      ...                 ...
# 792  2022045774      000  数媒静态设计专业组
# 793  2022045321      000      微课与教学辅助
# 794  2022045284      000      微课与教学辅助
# 795  2022046525      000  数媒静态设计专业组
# 796  2022046552      000  数媒静态设计专业组
#
# [797 rows x 3 columns]

# %%
df1.to_csv('runResult00.txt', sep='\t', index=False, header=True, encoding="utf-8")

# %%
def encode2(lst: list):
    referee, level = [], []
    for l in lst:
        token = l.split('(')
        referee.append(token[0])
        level.append(token[1][:-1])
    
    return referee, level

data2 = {
    '作品编号': [i for i in data1['作品编号'] for _ in range(3)],
    '评委姓名': np.array([encode2(text[i+1:i+4])[0] for i in range(0, len(text), 4)]).flatten(),
    '推荐等级': np.array([encode2(text[i+1:i+4])[1] for i in range(0, len(text), 4)]).flatten(),
}
df2 = pd.DataFrame(data=data2)
df2
# Out:
#         作品编号 评委姓名  推荐等级
# 0     2022004762     王维  强烈推荐
# 1     2022004762     张飞  强烈推荐
# 2     2022004762   潘金莲  强烈推荐
# 3     2022037724   蒋晶晶  强烈推荐
# 4     2022037724     蔡旭  强烈推荐
# ...          ...      ...       ...
# 2386  2022046525   刘菊红    不推荐
# 2387  2022046525   韩华静    不推荐
# 2388  2022046552     魏巍    不推荐
# 2389  2022046552   刘菊红    不推荐
# 2390  2022046552   韩华静    不推荐
#
# [2391 rows x 3 columns]

# %%
df2.to_csv('runResult01.txt', sep='\t', index=False, header=True, encoding="utf-8")
